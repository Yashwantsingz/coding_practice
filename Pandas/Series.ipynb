# %%
#Series

# %%
import numpy as np
import pandas as pd
label=['a1','b2','c3']
my_lis=[10,20,30]
n1=np.array([10,20,30])
d={'a':10,'b':20,'c':30}

# %%
pd.Series(my_lis) #if label not given it will take index as label
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(n1,index=labels) # to customize labels use index=
# Out:
# a1    10
# b2    20
# c3    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data={
    "Name":['John', "Anna","Peter", "Linda"],
    'Age':[28,34, 29, 42],
    'City':['New York',"Paris","Berlin", "London"],
    'Salary':[65000, 70000, 62000, 85000]
}
df=pd.DataFrame(data_list)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list=[
    ['John',28,'New York',65000 ],
    ["Anna",34,"Paris",70000 ],
    ["Peter",29,"Berlin",62000], 
    ["Linda",42,"London",85000]
]
column=["Name","Age","City","Salary"]
row=[1,2,3,4]
df2=pd.DataFrame(data_list,columns=column)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2[['Name','City']] #selecting columns
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2.loc[[0,1]] #selecting rows
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2.iloc[[0,1]][["City","Salary"]]# selecting subset of rows and columns
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2[(df2["Age"]>30) & (df2["City"]=="Paris"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)    360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...
