# %%
#Series

# %%
import numpy as np
import pandas as pd
label=['a1','b2','c3']
my_lis=[10,20,30]
n1=np.array([10,20,30])
d={'a':10,'b':20,'c':30}

# %%
pd.Series(my_lis) #if label not given it will take index as label
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(n1,index=label) # to customize labels use index=
# Out:
# a1    10
# b2    20
# c3    30
# dtype: int64
