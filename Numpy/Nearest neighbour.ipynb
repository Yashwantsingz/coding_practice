# %%
import numpy as np
from math import sqrt

# %%
houses=np.random.randint(0,100,(10,2))  #maps
houses
# Out:
# array([[34,  0],
#        [28, 49],
#        [31,  3],
#        [62, 75],
#        [72, 40],
#        [88, 93],
#        [40, 89],
#        [96, 30],
#        [78, 29],
#        [72, 66]])

# %%
pos=np.random.randint(0,100,(1,2)) #my address
pos
# Out:
# array([[91, 43]])

# %%
distance=houses-pos
far=np.linalg.norm(distance,axis=1)
np.argmin(far)
# Out:
# np.int64(7)
