# %%
import numpy as np

# %%
arr=np.random.randint(0,100,(20,5))
student_avg=np.mean(arr,axis=1)
subject_avg=np.mean(arr,axis=0)
print(matrix[student_avg>80])
# Out:
# array([], shape=(0, 5), dtype=int64)

# %%
# Out:
# array([[66, 63, 59, 80, 34],
#        [86, 58, 72, 33, 96],
#        [75, 76, 83, 87, 13],
#        [52, 98, 88, 89, 34],
#        [66, 63, 59, 80, 34],
#        [86, 58, 72, 33, 96],
#        [75, 76, 83, 87, 13]])
